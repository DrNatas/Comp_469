# %% [markdown]
# # COMP 469 Lab 2: Uninformed Search Algorithms
# **Week 2** - AIMA Chapter 3
#
# Implement BFS, DFS, and UCS.

# %%
from collections import deque

# TODO: Implement graph search algorithms
def breadth_first_search(problem):
    # Your code here
    pass

print('Lab 2 starter ready. Implement search algorithms and test on Romania map or mazes.')
