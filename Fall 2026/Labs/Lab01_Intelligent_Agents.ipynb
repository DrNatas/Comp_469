# %% [markdown]
# # COMP 469 Lab 1: Intelligent Agents
# **Week 1** - AIMA Chapters 1 & 2
#
# In this lab you will implement different types of agents in a simple Vacuum World environment.

# %%
import random
import matplotlib.pyplot as plt

# TODO: Define the Vacuum Environment class
class VacuumEnvironment:
    def __init__(self, width=5, height=5):
        self.width = width
        self.height = height
        self.status = {}  # (x,y) -> 'Clean' or 'Dirty'
        # Initialize random dirt
        for x in range(width):
            for y in range(height):
                self.status[(x,y)] = 'Dirty' if random.random() < 0.3 else 'Clean'

# TODO: Define base Agent class and specific agents (Reflex, Model-based, etc.)

# Run simulations and compare performance
print('Lab 1 starter notebook ready. Implement agents and run simulations!')
