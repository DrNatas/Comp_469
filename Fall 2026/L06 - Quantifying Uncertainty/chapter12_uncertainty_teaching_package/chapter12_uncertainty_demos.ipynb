# %% [markdown]
# # Chapter 12: Quantifying Uncertainty demos
#
# Run these cells in order. The notebook imports the companion `chapter12_uncertainty_demos.py` file in the same folder.

# %%
from chapter12_uncertainty_demos import (
    expected_utility_demo,
    full_joint_demo,
    bayes_demo,
    naive_bayes_demo,
    wumpus_demo,
)

# %% [markdown]
# ## Demo 1: Maximum expected utility
# Compare airport plans by probability-weighted utility.

# %%
expected_utility_demo()

# %% [markdown]
# ## Demo 2: Inference using the full joint distribution
# Use the Toothache-Cavity-Catch table to compute posteriors.

# %%
full_joint_demo()

# %% [markdown]
# ## Demo 3: Bayes' rule and base rates
# Show how changing the prior changes the posterior.

# %%
bayes_demo()

# %% [markdown]
# ## Demo 4: Naive Bayes text classification
# Train a tiny classifier and classify short documents.

# %%
naive_bayes_demo()

# %% [markdown]
# ## Demo 5: Wumpus world pit probabilities
# Enumerate pit configurations consistent with breeze evidence.

# %%
wumpus_demo()
